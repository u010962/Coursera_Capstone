# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anton Lischewski**
#
# Senior Project Manager

# %% [markdown]
# *I am interested in data science because it will be important as an additional skill for any occupation in the near future*

# %% [markdown]
# ### The code in the following cell does nothing useful, except that it prints the string "Hello World"

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ---
#
# * Item 1
# * Item 2
#
# https://www.google.com
